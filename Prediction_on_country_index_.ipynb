# %% [markdown]
# <a href="https://colab.research.google.com/github/Odigie43/prediction-on-country/blob/main/Prediction_on_country_index_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# **Drive module import:** The drive module is imported from the google.colab library in the first line. Working with Google Drive in Google Colab is made possible by this module.
#
# **Mounting Google Drive:** You can mount your Google Drive in the Colab environment by using the second line of code. This code will generate a link when it is executed. You will receive a code after clicking the link and granting access to your Google Drive. This code may be copied and pasted back into the Colab cell to mount your Google Drive to the preferred path—in this example, '/content/drive').
#
#
#
# You will be able to use your Colab notebook to access your Google Drive directly after running this code. When you wish to read or save files to and from your Google Drive inside of the Colab environment, this is helpful.

# %%
# importing all the libraries for the work and seaborn is for plotting
# numpy, pandas and matplot for feature engineering,descriptive analysis etc
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# **Remarks:** The lines that begin with # are comments. Comments are meant to help human readers comprehend the objective of the code; they are not executed as code.
#
# How to Import Libraries
#
# **NumPy:** NumPy is a Python library for numerical computations. Large, multidimensional arrays and matrices are supported, as are mathematical operations on these arrays.
#
# **Pandas (pd):** Pandas is a package for data manipulation and analysis. It offers data structures that are effective for handling structured data, such as DataFrames.
#
# **Seaborn:** Seaborn is a Matplotlib-based library for data visualisation. It offers an advanced drawing interface for creating eye-catching and educational statistical visuals.
#
# **Matplotlib:** Matplotlib is a Python plotting package. Python visualisations that are static, interactive, and animated can be made using it.

# %%
default = pd.read_csv('/content/ify dataset.csv')

# %% [markdown]
# Pd.read_csv is the abbreviation for the Pandas library, and read_csv is a function that Pandas offers. Data from a CSV file can be read using this function.
#
# "/content/ify dataset.csv" is the file path of the CSV file that you wish to view. The '/content/' directory is where the file 'ify dataset.csv' should be saved. In Google Colab, an online environment for executing Python code, the route /content/ is a frequent directory.
#
# default =...: The value obtained from reading the CSV file is put into the variable called default. Thus, a variable named default now contains the information from the CSV file.
#
#
# Simply expressed, this piece of code says, "Read the data from the CSV file named 'ify dataset.csv' and store it in a variable called default." You can use the default variable to work with the data from the CSV file in your Python code after running this line. Data science and analysis tasks frequently use this method to load and alter data.

# %% [markdown]
# #                        FEATURE ENGINEERING

# %%
default.head()
# Out:
#    Unnamed: 0      Country  Quality of Life Index  Purchasing Power Index  \
# 0           0      Denmark                 192.67                  100.88
# 1           1  Switzerland                 192.01                  119.53
# 2           2      Finland                 190.22                   99.93
# 3           3    Australia                 186.21                  107.31
# 4           4  Netherlands                 183.67                   90.73
#
#    Safety Index  Health Care Index  Cost of Living Index  \
# 0         74.90              80.00                 83.00
# 1         78.40              72.44                122.40
# 2         76.68              75.79                 70.29
# 3         58.64              77.38                 73.54
# 4         72.38              74.65                 73.75
#
#    Property Price to Income Ratio  Traffic Commute Time Index  \
# 0                            7.45                       28.85
# ...

# %% [markdown]
# default: Use pd.read_csv('/content/ify dataset.csv') to construct a Pandas DataFrame with this name after reading data from a CSV file. Data from the CSV file are displayed in the default DataFrame.
#
# To access the initial few rows of a DataFrame, utilise the Pandas method.head(). You can change the number inside the parenthesis to view a different number of rows, but by default, it returns the first five rows.
#
#
# As a result, when you execute default.head(), your DataFrame default's top five rows are displayed, letting you rapidly examine the organisation and substance of your data. In order to determine whether the data has been loaded correctly and to obtain an impression of the dataset's appearance, this is a standard procedure in data analysis.
# So from the analysis, it shows that the dataset was loaded correctly.

# %%
# To print the first five columns
default.tail()
# Out:
#     Unnamed: 0     Country  Quality of Life Index  Purchasing Power Index  \
# 73          75   Sri Lanka                  85.16                   24.45
# 74          76        Iran                  74.14                   22.69
# 75          77       Kenya                  70.56                   27.32
# 76          78  Bangladesh                  70.03                   33.21
# 77          79     Nigeria                  55.65                   13.52
#
#     Safety Index  Health Care Index  Cost of Living Index  \
# 73         59.78              72.53                 31.61
# 74         50.75              51.70                 39.01
# 75         38.34              55.59                 40.21
# 76         36.06              42.80                 32.25
# 77         36.23              51.59                 31.00
#
#     Property Price to Income Ratio  Traffic Commute Time Index  \
# 73                           31.14                       59.01
# ...

# %% [markdown]
# default: This is the name of the DataFrame you have been using for Pandas. Like in your prior code example, it was probably made by reading data from a CSV file.
#
# A Pandas method called "tail()" can be used to obtain a DataFrame's final few rows. You can give a different number inside the parenthesis if you wish to see a different number of rows; by default, it returns the previous five rows.
#
# Therefore, the last five rows of your DataFrame default are displayed when you call default.tail(). This is helpful in determining the dataset's end, particularly when dealing with huge DataFrames. It aids in giving you an idea of the general organisation of the data and makes sure you haven't overlooked anything.
#
# To summarise, default.tail() provides a convenient means of inspecting the end of your DataFrame to gain a deeper understanding of the contents.

# %%
# to know the dimension, that shape we the command below
default.shape
# Out:
# (78, 20)

# %% [markdown]
# default: You have probably generated a Pandas DataFrame by reading data from a CSV file, and this is its name.
#
# .shape is an attribute of a Pandas DataFrame rather than a method. A tuple containing the DataFrame's dimensions is returned when you retrieve the.shape file. The number of rows is the first member of the tuple, while the number of columns is the second.
#
# Thus, the result you receive from running default.shape is something like (rows, columns), where rows denotes the number of rows and columns the number of columns in your DataFrame.
#
# Your DataFrame comprises 78 rows and 20 columns, for instance, if the output is (78, 20).
#
#
# Knowing the form of your DataFrame is essential since it allows you to quickly assess the amount of your dataset and facilitates the efficient planning and execution of data analysis jobs.

# %%
## To display evertything, that is all the columns , we use the command below
pd.options.display.max_columns = None
default.head()
# Out:
#    Unnamed: 0      Country  Quality of Life Index  Purchasing Power Index  \
# 0           0      Denmark                 192.67                  100.88
# 1           1  Switzerland                 192.01                  119.53
# 2           2      Finland                 190.22                   99.93
# 3           3    Australia                 186.21                  107.31
# 4           4  Netherlands                 183.67                   90.73
#
#    Safety Index  Health Care Index  Cost of Living Index  \
# 0         74.90              80.00                 83.00
# 1         78.40              72.44                122.40
# 2         76.68              75.79                 70.29
# 3         58.64              77.38                 73.54
# 4         72.38              74.65                 73.75
#
#    Property Price to Income Ratio  Traffic Commute Time Index  \
# 0                            7.45                       28.85
# ...

# %% [markdown]
# **max_columns = None in pd.options.display**:
#
# The Pandas library is abbreviated as pd.
# The term "pd.options" describes the global choices or settings in Pandas that regulate the way the data is displayed by the programme.
# One of these options is display.max_columns, which modifies the maximum number of columns that a DataFrame will print with.
# You are effectively instructing Pandas to display all the columns without truncation by setting it to None.
# Default.head():
#
# Default refers to the name of the Pandas DataFrame that you have been utilising, most likely obtained from a CSV file.The DataFrame's initial five rows are displayed using the head() method (by default, the first 5 rows).
#
# By combining these two lines of code, you may show the first few rows of the default DataFrame and change Pandas' display settings to show all columns without truncation.
#
# Seeing every column in the output is guaranteed, which might be helpful when working with datasets that have a lot of columns. In the event that max_columns is not set to None, Pandas may truncate the display to a predetermined number of columns, which may result in incomplete output.
#
# To improve accessibility and comprehension of the dataset, these lines of code, in summary, modify the display settings to show all columns and then display the first few rows of the DataFrame.

# %%
## using the index number to find the total numbers of rows and columns(row index 0, column index 1)
print("The total number of rows in this dataset is", default.shape[0])
print("The total number of columns in this dataset is", default.shape[1])
# Out:
# The total number of rows in this dataset is 78
# The total number of columns in this dataset is 20

# %% [markdown]
# **print(default.shape[0]),** "The total number of rows in this dataset is").
#
# The Python function print() is pre-installed and can be used to print text or variable values to the console.
# The string "The total number of rows in this dataset is" will be included in the output.
# The first member of the tuple that default.shape returns, representing the total number of rows in the DataFrame, is retrieved via default.shape[0].
# Thus, the real number of rows in the default DataFrame is printed along with a message on this line.
#
# **print(default.shape[1]),** "The total number of columns in this dataset is").
#
# This print() statement prints the actual number of columns in the default DataFrame in addition to a message, just like the previous one did.
# The second element of the tuple supplied by default.shape, the total number of columns, is retrieved by calling default.shape[1].
# Thus, two lines of text will be produced when you run this code. The dataset's total number of rows is indicated in the first line, and its total number of columns is indicated in the second. This is a typical method of giving a brief overview of the dataset's dimensions that you are using.

# %%
# Display the column names of your DataFrame
print("Column Names:")
print(default.columns)
# Out:
# Column Names:
# Index(['Unnamed: 0', 'Country', 'Quality of Life Index',
#        'Purchasing Power Index', 'Safety Index', 'Health Care Index',
#        'Cost of Living Index', 'Property Price to Income Ratio',
#        'Traffic Commute Time Index', 'Pollution Index', 'Climate Index',
#        'Population', 'Density pop./km2', 'Population source', 'Crime Index',
#        'Rent Index', 'Cost of Living Plus Rent Index', 'Groceries Index',
#        'Restaurant Price Index', 'Local Purchasing Power Index',
#        'Population Band'],
#       dtype='object')

# %%
# to information about our dataset like total numbers of rows , columns
## and  know the various types datatype used in each  column and the memory requirement

default.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 78 entries, 0 to 77
# Data columns (total 20 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Unnamed: 0                      78 non-null     int64
#  1   Country                         78 non-null     object
#  2   Quality of Life Index           78 non-null     float64
#  3   Purchasing Power Index          78 non-null     float64
#  4   Safety Index                    78 non-null     float64
#  5   Health Care Index               78 non-null     float64
#  6   Cost of Living Index            78 non-null     float64
#  7   Property Price to Income Ratio  78 non-null     float64
#  8   Traffic Commute Time Index      78 non-null     float64
#  9   Pollution Index                 78 non-null     float64
#  10  Climate Index                   78 non-null     float64
#  11  Population                      78 non-null     int64
# ...

# %%
## to check for null values and which shows that there is no null value in the dataset
default.isnull()
# Out:
#     Unnamed: 0  Country  Quality of Life Index  Purchasing Power Index  \
# 0        False    False                  False                   False
# 1        False    False                  False                   False
# 2        False    False                  False                   False
# 3        False    False                  False                   False
# 4        False    False                  False                   False
# ..         ...      ...                    ...                     ...
# 73       False    False                  False                   False
# 74       False    False                  False                   False
# 75       False    False                  False                   False
# 76       False    False                  False                   False
# 77       False    False                  False                   False
#
#     Safety Index  Health Care Index  Cost of Living Index  \
# ...

# %% [markdown]
# #       BIG DATA PROCESSING  QUESTIONS AND ANWERS

# %% [markdown]
# QUESTION 1
# 1. Consider the following columns in our data set: Population, Population source, Quality of Life Index, Pollution Index. What are the types of each of these columns in terms of :
# (i) Numerical discrete, numerical continuous, categorical
#
# ANSWER
#
# **Population:** this is  Because a continuous variable can take any actual value within a range, it is said to be numerically continuous. It is not restricted to any particular whole number, and decimal values are supported.
#
# **Population source:** is classified as categorical since it usually shows labels or categories indicating the source from which the population data is gathered. Distinct classes or groups are represented by discrete categories.
#
# Since the **Quality of Life Index** is a continuous variable with a range of possible actual values, it is numerically continuous. It's a measurement scale with decimal values that isn't restricted to certain whole integers.
#
# Since the **pollution index **is a continuous variable that gauges the amount of pollution in a given location, it is numerically continuous.
#
#
#  (ii) Measurement scale (nominal, ordinal, interval, ratio)
#
# Measurement of the population A scale is a ratio.
#
# Justification: Because population has a true zero point—that is, the lack of population—and because ratios between values have meaning, population is a ratio variable.
#
# population source : There is no measurement scale.
# Reason: A nominal variable is the population source. There is no intrinsic ranking or order to the categories (sources). They are all separate.
#
# Measurement Scale:** Quality of Life Index**  Reasoning for Intervals: An interval variable is the Quality of Life Index. Both the meaningful order and the relevant variances between values are present.
#
# Measurement Scale is a ratio for the **pollution index**.
# Justification: Index of Pollution is a ratio variable. Similar to population, pollution has a true zero point, and ratios between levels have significance.

# %% [markdown]
# QUESTION TWO
#
# (i) What measures of central tendency do you think are the most suitable for each of the columns and why?
#
# **Answer**
#
#  i will chose mean because mean is appropriate for numerical columns devoid of notable outliers and with a distribution that is broadly symmetric. The central tendency is balanced when represented by the mean.

# %%
# to calculate the mean of the columns in the dataset
default.describe()
# Out:
#        Unnamed: 0  Quality of Life Index  Purchasing Power Index  \
# count   78.000000              78.000000               78.000000
# mean    39.333333             134.361026               60.266538
# std     23.513283              34.317800               27.143570
# min      0.000000              55.650000               13.520000
# 25%     19.250000             106.012500               36.240000
# 50%     38.500000             133.950000               57.175000
# 75%     59.750000             162.605000               84.502500
# max     79.000000             192.670000              119.530000
#
#        Safety Index  Health Care Index  Cost of Living Index  \
# count     78.000000          78.000000             78.000000
# mean      61.322692          64.983333             52.690897
# std       13.872969           9.860920             19.937181
# min       22.510000          42.800000             21.980000
# 25%       53.447500          56.682500             37.360000
# ...

# %% [markdown]
# # The function of the above code   Describe():`**
#
# Using this Pandas technique, is use create descriptive statistics(central tendency) for the numerical columns in the DataFrame.
# Run default.describe() to obtain a new DataFrame with many statistics for each numerical column: count, mean, standard deviation, minimum, median (50th percentile), first quartile (25th percentile), third quartile (75th percentile), and maximum.
#
# You can easily determine the distribution and central tendency of your numerical data by looking at the output of default.describe(). You can learn more about the distribution's shape, central location, and extent by reading this overview of the major statistical measures for each numerical column.

# %% [markdown]
# ## (ii) Write Python code to compute each of the measures of central tendency from the question (I)

# %%
import pandas as pd

# Assuming 'default' is your DataFrame
# Replace 'your_file_path.csv' with the actual file path if needed
# default = pd.read_csv('your_file_path.csv')

# Display the first few rows of the DataFrame
print("Preview of the DataFrame:")
print(default.head())

# Compute measures of central tendency
columns_of_interest = ["Population", "Quality of Life Index", "Pollution Index"]
for column in columns_of_interest:
    print("\nColumn:", column)
    print("Mean:", default[column].mean())
    print("Median:", default[column].median())
    print("Mode:")
    print(default[column].mode())
    print("="*30)
# Out:
# Preview of the DataFrame:
#    Unnamed: 0      Country  Quality of Life Index  Purchasing Power Index  \
# 0           0      Denmark                 192.67                  100.88
# 1           1  Switzerland                 192.01                  119.53
# 2           2      Finland                 190.22                   99.93
# 3           3    Australia                 186.21                  107.31
# 4           4  Netherlands                 183.67                   90.73
#
#    Safety Index  Health Care Index  Cost of Living Index  \
# 0         74.90              80.00                 83.00
# 1         78.40              72.44                122.40
# 2         76.68              75.79                 70.29
# 3         58.64              77.38                 73.54
# 4         72.38              74.65                 73.75
#
#    Property Price to Income Ratio  Traffic Commute Time Index  \
# 0                            7.45                       28.85
# ...

# %% [markdown]
# # Analysis to above results
#
# # The Pollution Index
#
# Mean: 53.21846415381841526
# The median is 57.125.
# Justification: The average value of the Pollution Index over all observations is represented by the mean, a measure of central tendency. It is roughly 53.22 in this instance. Conversely, when the values are arranged in ascending order, the median represents the midway value of the Pollution Index. Because the mean is smaller than the median, there may be some lower values dragging the average down, which could indicate a potential skewness towards lower values.
#
# # The Quality of Life Index:
#
# mean of  134.36102564102563
# The median is 133.95.
# Justification: This is the average value of the Quality of Life Index over all observations, which is roughly 134.36. The median, at 133.95, is extremely near to the mean. According to this, there appears to be no noticeable skewness in the Quality of Life Index distribution, which is generally symmetrical.
#
# # population:
#
# Average: 88223073.23076923
# 180196642.0 is the median.
# Justification: About 80,823,073 people make up the mean population, while 18,019,642 people make up the median. Given the significant discrepancy between the mean and median, it is likely that a few number of extremely high population values have skewed the distribution of population values, pushing the average upward. In this instance, the centre tendency is better represented by the median since it is less susceptible to extreme extremes.

# %% [markdown]
# # (iii) Write Python code to compute the standard deviation of the above four columns for which standard deviation makes sense
#
# An indicator of how much variation or dispersion there is in a group of values is the standard deviation. Values are more widely distributed around the mean the higher the standard deviation.Standard Deviation for Population: 2.22090290.88693538 while Standard Deviation for Quality of Life Index: 34.317800295418365
# and Standard Deviation for Pollution Index: 20.917777381677304, its then shows that quality of life has a good indicator from the python code below.

# %%
import pandas as pd

# Assuming 'default' is your DataFrame
# Replace 'your_file_path.csv' with the actual file path if needed
# default = pd.read_csv('your_file_path.csv')

# Display the first few rows of the DataFrame
print("Preview of the DataFrame:")
print(default.head())

# Compute standard deviation for relevant columns
columns_of_interest = ["Population", "Quality of Life Index", "Pollution Index"]
for column in columns_of_interest:
    std_deviation = default[column].std()
    print(f"\nStandard Deviation for {column}: {std_deviation}")
    print("="*40)
# Out:
# Preview of the DataFrame:
#    Unnamed: 0      Country  Quality of Life Index  Purchasing Power Index  \
# 0           0      Denmark                 192.67                  100.88
# 1           1  Switzerland                 192.01                  119.53
# 2           2      Finland                 190.22                   99.93
# 3           3    Australia                 186.21                  107.31
# 4           4  Netherlands                 183.67                   90.73
#
#    Safety Index  Health Care Index  Cost of Living Index  \
# 0         74.90              80.00                 83.00
# 1         78.40              72.44                122.40
# 2         76.68              75.79                 70.29
# 3         58.64              77.38                 73.54
# 4         72.38              74.65                 73.75
#
#    Property Price to Income Ratio  Traffic Commute Time Index  \
# 0                            7.45                       28.85
# ...

# %% [markdown]
# # iv    Which measure would you use to compare which of the columns, Quality of Life index and Pollution Index, has more variability in the values? Write Python code to calculate this measure and based on that, conclude in which column there is more variability in the values.
#
# ANSWER
#
# In order to assess the degree of variability found in the values of the "Pollution Index" and "Quality of Life Index" columns, I would employ a distribution measure. The standard deviation, is the most often used metrics for describing dispersion. The standard deviation is an often utilised statistic as it offers an indication of the average dispersion of every data point from the mean.
#
# I would therefore compute and compare the standard deviations for the two columns. This is the justification:
#
# The standard deviation quantifies the degree to which a single data point deviates from the mean. More variety in the data is indicated by a higher standard deviation.
# helpful in comparing the distribution of data across various columns.
# The code below it shows that quality of life with STDV 34.317800295418365 has greater variability compare to pollution index

# %%
std_quality_of_life = default['Quality of Life Index'].std()
std_pollution = default['Pollution Index'].std()

print("Standard Deviation for Quality of Life Index:", std_quality_of_life)
print("Standard Deviation for Pollution Index:", std_pollution)
# Out:
# Standard Deviation for Quality of Life Index: 34.317800295418365
# Standard Deviation for Pollution Index: 20.917777381677304

# %% [markdown]
# 3 Write Python code that will print the names of all the countries that are outliers in term of the density of population per square km3 (Density pop./km2 column).
#
# After executing the code, it shows that Countries with Outliers in Density pop./km2:
#
# 33    Singapore
#
# 66    Hong Kong

# %%
import pandas as pd

# Assuming 'default' is your DataFrame
# Replace 'your_file_path.csv' with the actual file path if needed
# default = pd.read_csv('your_file_path.csv')

# Display the first few rows of the DataFrame
print("Preview of the DataFrame:")
print(default.head())

# Calculate Z-scores for the 'Density pop./km2' column
z_scores = (default['Density pop./km2'] - default['Density pop./km2'].mean()) / default['Density pop./km2'].std()

# Define a threshold for outliers (e.g., Z-score greater than 3)
outlier_threshold = 3

# Identify countries with Z-scores greater than the threshold
outliers = default[z_scores.abs() > outlier_threshold]

# Print the names of countries that are outliers
print("\nCountries with Outliers in Density pop./km2:")
print(outliers['Country'])
# Out:
# Preview of the DataFrame:
#    Unnamed: 0      Country  Quality of Life Index  Purchasing Power Index  \
# 0           0      Denmark                 192.67                  100.88
# 1           1  Switzerland                 192.01                  119.53
# 2           2      Finland                 190.22                   99.93
# 3           3    Australia                 186.21                  107.31
# 4           4  Netherlands                 183.67                   90.73
#
#    Safety Index  Health Care Index  Cost of Living Index  \
# 0         74.90              80.00                 83.00
# 1         78.40              72.44                122.40
# 2         76.68              75.79                 70.29
# 3         58.64              77.38                 73.54
# 4         72.38              74.65                 73.75
#
#    Property Price to Income Ratio  Traffic Commute Time Index  \
# 0                            7.45                       28.85
# ...

# %% [markdown]
# 4. Consider the following columns of our dataset: Quality of Life Index, Purchasing Power Index, Pollution Index, Safety Index, Cost of Living Index, Restaurant Price Index and Climate Index.
#
# (i) Which of these columns would you consider (positively or negatively) correlated with Quality of Life Index and would the correlation be strong, normal or weak?

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming 'default' is your DataFrame
# Replace 'your_file_path.csv' with the actual file path if needed
# default = pd.read_csv('your_file_path.csv')

# Select relevant columns for analysis
columns_of_interest = ["Quality of Life Index", "Purchasing Power Index", "Pollution Index",
                        "Safety Index", "Cost of Living Index", "Restaurant Price Index", "Climate Index"]

# Subset the DataFrame with the selected columns
subset_data = default[columns_of_interest]

# Calculate the correlation matrix
correlation_matrix = subset_data.corr()

# Plot the correlation heatmap using Seaborn
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap="coolwarm", fmt=".2f", linewidths=.5)
plt.title("Correlation Heatmap")
plt.show()

# Extract the correlation values for "Quality of Life Index"
quality_of_life_correlation = correlation_matrix["Quality of Life Index"]

# Print the correlation values
print("Correlation with Quality of Life Index:")
print(quality_of_life_correlation)
# Out:
# Correlation with Quality of Life Index:
# Quality of Life Index     1.000000
# Purchasing Power Index    0.844027
# Pollution Index          -0.900211
# Safety Index              0.592168
# Cost of Living Index      0.707451
# Restaurant Price Index    0.750574
# Climate Index             0.052183
# Name: Quality of Life Index, dtype: float64

# %% [markdown]
# From the code above, there is correlation between Correlation with Quality of Life Index with Quality of Life Index     1.000000, Purchasing Power Index    0.844027, Safety Index   0.592168, Cost of Living Index  0.707451, Restaurant Price Index    0.750574, Climate Index   0.052183, which all show weak correlation and negative correlation with pollution index

# %% [markdown]
# question 4
#
# (ii) Which two columns of the above have the strongest positive correlation between them?

# %%
import pandas as pd

# Assuming 'default' is your DataFrame
# Replace 'your_file_path.csv' with the actual file path if needed
# default = pd.read_csv('your_file_path.csv')

# Select relevant columns for analysis
columns_of_interest = ["Quality of Life Index", "Purchasing Power Index", "Pollution Index",
                        "Safety Index", "Cost of Living Index", "Restaurant Price Index", "Climate Index"]

# Subset the DataFrame with the selected columns
subset_data = default[columns_of_interest]

# Calculate the correlation matrix
correlation_matrix = subset_data.corr()

# Find the two columns with the strongest positive correlation
strongest_positive_correlation = correlation_matrix.unstack().sort_values(ascending=False).drop_duplicates()

# Extract column names with the strongest positive correlation
column1, column2 = strongest_positive_correlation.index[1]

# Print the result
print(f"The two columns with the strongest positive correlation are '{column1}' and '{column2}' with a correlation of {strongest_positive_correlation[1]:.2f}")
# Out:
# The two columns with the strongest positive correlation are 'Restaurant Price Index' and 'Cost of Living Index' with a correlation of 0.92

# %% [markdown]
# 5.Write a code to produce graphs in Python to visualise the following information:
#
# (I) How many countries are in the following bands based on population: small (less than 10,000,000), medium (10,000,000 – 100,000,000) and large (100,000,000+)

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming 'default' is your DataFrame
# Replace 'your_file_path.csv' with the actual file path if needed
# default = pd.read_csv('your_file_path.csv')

# Display the first few rows of the DataFrame
print("Preview of the DataFrame:")
print(default.head())

# Define population bands
small_band = 10000000
medium_band = 100000000

# Create a new column 'Population Band' based on population
default['Population Band'] = pd.cut(default['Population'], bins=[0, small_band, medium_band, float('inf')],
                                   labels=['Small (<10M)', 'Medium (10M-100M)', 'Large (100M+)'])

# Count the number of countries in each population band
band_counts = default['Population Band'].value_counts()

# Plot the bar chart
plt.figure(figsize=(8, 6))
band_counts.plot(kind='bar', color='skyblue')
plt.title('Number of Countries in Population Bands')
plt.xlabel('Population Band')
plt.ylabel('Number of Countries')
plt.show()
# Out:
# Preview of the DataFrame:
#    Unnamed: 0      Country  Quality of Life Index  Purchasing Power Index  \
# 0           0      Denmark                 192.67                  100.88
# 1           1  Switzerland                 192.01                  119.53
# 2           2      Finland                 190.22                   99.93
# 3           3    Australia                 186.21                  107.31
# 4           4  Netherlands                 183.67                   90.73
#
#    Safety Index  Health Care Index  Cost of Living Index  \
# 0         74.90              80.00                 83.00
# 1         78.40              72.44                122.40
# 2         76.68              75.79                 70.29
# 3         58.64              77.38                 73.54
# 4         72.38              74.65                 73.75
#
#    Property Price to Income Ratio  Traffic Commute Time Index  \
# 0                            7.45                       28.85
# ...

# %% [markdown]
# Explanation
#
# From the graph above, its shows that most countries with medium population are more in number followed by small number and lowest with large population

# %% [markdown]
# 5. ii. What percentage of population was obtained using each of the possible population sources (Official quarterly estimate, official provisional figure, Official estimate…)

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming 'default' is your DataFrame
# Replace 'your_file_path.csv' with the actual file path if needed
# default = pd.read_csv('your_file_path.csv')

# Display the first few rows of the DataFrame
print("Preview of the DataFrame:")
print(default.head())

# Group by 'Population source' and calculate the percentage of population for each source
population_percentage = default.groupby('Population source')['Population'].sum() / default['Population'].sum() * 100

# Plot the pie chart
plt.figure(figsize=(8, 8))

# Dynamically set explode based on the number of unique categories
explode_values = [0.1] * len(population_percentage)

population_percentage.plot(kind='pie', autopct='%1.1f%%', colors=['lightblue', 'lightcoral', 'lightgreen'],
                            wedgeprops=dict(width=0.3), explode=explode_values, shadow=True)

plt.title('Percentage of Population by Population Source')
plt.ylabel('')
plt.show()
# Out:
# Preview of the DataFrame:
#    Unnamed: 0      Country  Quality of Life Index  Purchasing Power Index  \
# 0           0      Denmark                 192.67                  100.88
# 1           1  Switzerland                 192.01                  119.53
# 2           2      Finland                 190.22                   99.93
# 3           3    Australia                 186.21                  107.31
# 4           4  Netherlands                 183.67                   90.73
#
#    Safety Index  Health Care Index  Cost of Living Index  \
# 0         74.90              80.00                 83.00
# 1         78.40              72.44                122.40
# 2         76.68              75.79                 70.29
# 3         58.64              77.38                 73.54
# 4         72.38              74.65                 73.75
#
#    Property Price to Income Ratio  Traffic Commute Time Index  \
# 0                            7.45                       28.85
# ...

# %% [markdown]
# 5. (iii) How strong is correlation between Quality of Life Index and Safety Index correlate?

# %%
# Scatter plot with regression line
plt.figure(figsize=(8, 6))
sns.regplot(x='Quality of Life Index', y='Safety Index', data=default, color='skyblue')
plt.title('Correlation Between Quality of Life Index and Safety Index with Regression Line')
plt.xlabel('Quality of Life Index')
plt.ylabel('Safety Index')
plt.show()

# %% [markdown]
# 5 (111) OR YOU CAN USE THE CODE ALSO

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming 'default' is your DataFrame
# Replace 'your_file_path.csv' with the actual file path if needed
# default = pd.read_csv('your_file_path.csv')

# Display the first few rows of the DataFrame
print("Preview of the DataFrame:")
print(default.head())

# Scatter plot to visualize the correlation
plt.figure(figsize=(8, 6))
sns.scatterplot(x='Quality of Life Index', y='Safety Index', data=default, color='skyblue')
plt.title('Correlation Between Quality of Life Index and Safety Index')
plt.xlabel('Quality of Life Index')
plt.ylabel('Safety Index')
plt.show()
# Out:
# Preview of the DataFrame:
#    Unnamed: 0      Country  Quality of Life Index  Purchasing Power Index  \
# 0           0      Denmark                 192.67                  100.88
# 1           1  Switzerland                 192.01                  119.53
# 2           2      Finland                 190.22                   99.93
# 3           3    Australia                 186.21                  107.31
# 4           4  Netherlands                 183.67                   90.73
#
#    Safety Index  Health Care Index  Cost of Living Index  \
# 0         74.90              80.00                 83.00
# 1         78.40              72.44                122.40
# 2         76.68              75.79                 70.29
# 3         58.64              77.38                 73.54
# 4         72.38              74.65                 73.75
#
#    Property Price to Income Ratio  Traffic Commute Time Index  \
# 0                            7.45                       28.85
# ...

# %% [markdown]
# 5. (Iv) How is Cost of Living Index  distributed (i.e. how many countries are in each band) in 10 bands of equal length, from minimum to maximum value of the index?

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming 'default' is your DataFrame
# Replace 'your_file_path.csv' with the actual file path if needed
# default = pd.read_csv('your_file_path.csv')

# Display the first few rows of the DataFrame
print("Preview of the DataFrame:")
print(default.head())

# Plot histogram to visualize the distribution
plt.figure(figsize=(10, 6))
plt.hist(default['Cost of Living Index'], bins=10, edgecolor='black', color='skyblue')
plt.title('Distribution of Cost of Living Index')
plt.xlabel('Cost of Living Index')
plt.ylabel('Number of Countries')
plt.show()
# Out:
# Preview of the DataFrame:
#    Unnamed: 0      Country  Quality of Life Index  Purchasing Power Index  \
# 0           0      Denmark                 192.67                  100.88
# 1           1  Switzerland                 192.01                  119.53
# 2           2      Finland                 190.22                   99.93
# 3           3    Australia                 186.21                  107.31
# 4           4  Netherlands                 183.67                   90.73
#
#    Safety Index  Health Care Index  Cost of Living Index  \
# 0         74.90              80.00                 83.00
# 1         78.40              72.44                122.40
# 2         76.68              75.79                 70.29
# 3         58.64              77.38                 73.54
# 4         72.38              74.65                 73.75
#
#    Property Price to Income Ratio  Traffic Commute Time Index  \
# 0                            7.45                       28.85
# ...

# %% [markdown]
# The above showed the cost of living of different countries according to living index.

# %% [markdown]
# By Emmanuel okohe
